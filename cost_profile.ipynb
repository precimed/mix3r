# %%
import matplotlib.pyplot as plt

# %%
cost_scz_adhd_aud_4 = [37491.9570312, 37491.9101562, 37491.8632812, 37491.8164062, 37491.2070312, 37491.1562500, 37491.1054688, 37491.0664062, 37491.0234375, 37491.0039062, 37490.9648438, 37490.9375000, 37490.9179688, 37490.9101562, 37490.9023438, 37490.9140625]
p123_scz_adhd_aud_4 = [3.3970724e-04, 3.5660485e-04, 3.7434297e-04, 3.9296342e-04, 4.1251008e-04, 4.3302903e-04, 4.5456862e-04, 4.7717963e-04, 5.0091535e-04, 5.2583172e-04, 5.5198747e-04, 5.7944426e-04, 6.0826679e-04, 6.3852301e-04, 6.7028422e-04, 7.0362528e-04]

# %%
fig, ax = plt.subplots(1, 1, figsize=(7,4), constrained_layout=True)    
# configure spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)
ax.set_xlabel(r"$\mathrm{p_{123}}$", fontsize=14)
ax.set_ylabel("Cost", fontsize=14)
#ax.spines['left'].set_position(('outward',5))
plt.plot(p123_scz_adhd_aud_4, cost_scz_adhd_aud_4)

# %%
cost_sa_adhd_gge_1 = [27751.9140625, 27751.9140625, 27751.9101562, 27751.9101562, 27751.9062500, 27751.9042969, 27751.8984375, 27751.8906250, 27751.8789062, 27751.8652344, 27751.8476562, 27751.8261719, 27751.7988281, 27751.7656250, 27751.7363281, 27751.7167969]
p123_sa_adhd_gge_1 = [1.0000000e-06, 1.4332119e-06, 2.0540964e-06, 2.9439555e-06, 4.2193121e-06, 6.0471685e-06, 8.6668740e-06, 1.2421467e-05, 1.7802595e-05, 2.5514891e-05, 3.6568247e-05, 5.2410047e-05, 7.5114704e-05, 1.0765529e-04, 1.5429285e-04, 2.2113435e-04]

fig, ax = plt.subplots(1, 1, figsize=(7,4), constrained_layout=True)    
# configure spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)
ax.set_xlabel(r"$\mathrm{p_{123}}$", fontsize=14)
ax.set_ylabel("Cost", fontsize=14)
#ax.spines['left'].set_position(('outward',5))
plt.plot(p123_sa_adhd_gge_1, cost_sa_adhd_gge_1)

# %%
cost_aud_adhd_gge_9 = [27894.0917969, 27894.0917969, 27894.0917969, 27894.0957031, 27894.0957031, 27894.0957031, 27894.0957031, 27894.0976562, 27894.0976562, 27894.0996094, 27894.0996094, 27894.0996094, 27894.0996094, 27894.0996094, 27894.1015625, 27894.1035156]
p123_aud_adhd_gge_9 = [1.9706279e-04, 1.9766466e-04, 1.9826837e-04, 1.9887393e-04, 1.9948133e-04, 2.0009059e-04, 2.0070170e-04, 2.0131469e-04, 2.0192955e-04, 2.0254628e-04, 2.0316490e-04, 2.0378541e-04, 2.0440781e-04, 2.0503212e-04, 2.0565833e-04, 2.0628645e-04]

fig, ax = plt.subplots(1, 1, figsize=(7,4), constrained_layout=True)    
# configure spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)
ax.set_xlabel(r"$\mathrm{p_{123}}$", fontsize=14)
ax.set_ylabel("Cost", fontsize=14)
#ax.spines['left'].set_position(('outward',5))
plt.plot(p123_aud_adhd_gge_9, cost_aud_adhd_gge_9)
